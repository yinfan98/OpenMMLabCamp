# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openmim in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.10/dist-packages (from openmim) (0.1.11)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.27.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.4.3)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Requirement already satisfied: mmengine in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.3.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmengine) (0.40.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.14.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.0-cp310-cp310-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from mmcv) (0.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv) (0.40.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv) (2.3.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv) (3.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.2.0->mmcv) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.2.0->mmcv) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0

# %%
# !pip install opencv-python pillow matplotlib seaborn tqdm pytorch-lightning 'mmdet>=3.0.0rc1' -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: mmdet>=3.0.0rc1 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.0.1+cu118)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.4.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (0.11.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (0.8.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc1) (2.0.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc1) (1.10.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc1) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc1) (1.16.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc1) (3.1.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.27.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)

# %%
# !git clone https://github.com/open-mmlab/mmsegmentation.git -b dev-1.x
# Out:
# fatal: destination path 'mmsegmentation' already exists and is not an empty directory.

# %%
import os
os.chdir('mmsegmentation')

# %%
# !python setup.py install

# !pip install -v -e .
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing mmsegmentation.egg-info/PKG-INFO
# writing dependency_links to mmsegmentation.egg-info/dependency_links.txt
# writing requirements to mmsegmentation.egg-info/requires.txt
# writing top-level names to mmsegmentation.egg-info/top_level.txt
# reading manifest file 'mmsegmentation.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/tests
# copying tests/test_sampler.py -> build/lib/tests
# copying tests/test_digit_version.py -> build/lib/tests
# copying tests/__init__.py -> build/lib/tests
# copying tests/test_config.py -> build/lib/tests
# creating build/lib/mmseg
# copying mmseg/__init__.py -> build/lib/mmseg
# copying mmseg/version.py -> build/lib/mmseg
# creating build/lib/tests/test_models
# copying tests/test_models/test_data_preprocessor.py -> build/lib/tests/test_models
# copying tests/test_models/__init__.py -> build/lib/tests/test_models
# copying tests/test_models/test_forward.py -> build/lib/tests/test_models
# creating build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_setr_mla_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_setr_up_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_uper_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_psp_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_dnl_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_aspp_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_apc_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_segformer_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_ham_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_dm_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_gc_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_decode_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_cc_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_isa_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/utils.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_maskformer_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_segmenter_mask_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_ocr_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_fcn_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_ann_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_pidnet_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_dpt_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_mask2former_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_nl_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/__init__.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_lraspp_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_ema_head.py -> build/lib/tests/test_models/test_heads
# copying tests/test_models/test_heads/test_psa_head.py -> build/lib/tests/test_models/test_heads
# creating build/lib/tests/test_models/test_utils
# copying tests/test_models/test_utils/test_shape_convert.py -> build/lib/tests/test_models/test_utils
# copying tests/test_models/test_utils/test_embed.py -> build/lib/tests/test_models/test_utils
# copying tests/test_models/test_utils/__init__.py -> build/lib/tests/test_models/test_utils
# creating build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_jpu.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_ic_neck.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_fpn.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_multilevel_neck.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/__init__.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_mla_neck.py -> build/lib/tests/test_models/test_necks
# copying tests/test_models/test_necks/test_feature2pyramid.py -> build/lib/tests/test_models/test_necks
# creating build/lib/tests/test_models/test_segmentors
# copying tests/test_models/test_segmentors/utils.py -> build/lib/tests/test_models/test_segmentors
# copying tests/test_models/test_segmentors/test_seg_tta_model.py -> build/lib/tests/test_models/test_segmentors
# copying tests/test_models/test_segmentors/__init__.py -> build/lib/tests/test_models/test_segmentors
# copying tests/test_models/test_segmentors/test_encoder_decoder.py -> build/lib/tests/test_models/test_segmentors
# copying tests/test_models/test_segmentors/test_cascade_encoder_decoder.py -> build/lib/tests/test_models/test_segmentors
# creating build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_vit.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_unet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_mit.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_pidnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_resnext.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_blocks.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_erfnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_bisenetv2.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/utils.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_cgnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_swin.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_mobilenet_v3.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_bisenetv1.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_beit.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_fast_scnn.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_twins.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_icnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_stdc.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_mscan.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_resnest.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_hrnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/__init__.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_mae.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_resnet.py -> build/lib/tests/test_models/test_backbones
# copying tests/test_models/test_backbones/test_timm_backbone.py -> build/lib/tests/test_models/test_backbones
# creating build/lib/mmseg/utils
# copying mmseg/utils/io.py -> build/lib/mmseg/utils
# copying mmseg/utils/typing_utils.py -> build/lib/mmseg/utils
# copying mmseg/utils/collect_env.py -> build/lib/mmseg/utils
# copying mmseg/utils/set_env.py -> build/lib/mmseg/utils
# copying mmseg/utils/__init__.py -> build/lib/mmseg/utils
# copying mmseg/utils/class_names.py -> build/lib/mmseg/utils
# copying mmseg/utils/misc.py -> build/lib/mmseg/utils
# creating build/lib/mmseg/apis
# copying mmseg/apis/inference.py -> build/lib/mmseg/apis
# copying mmseg/apis/mmseg_inferencer.py -> build/lib/mmseg/apis
# copying mmseg/apis/__init__.py -> build/lib/mmseg/apis
# creating build/lib/mmseg/registry
# copying mmseg/registry/__init__.py -> build/lib/mmseg/registry
# copying mmseg/registry/registry.py -> build/lib/mmseg/registry
# creating build/lib/mmseg/datasets
# copying mmseg/datasets/dsdl.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/hrf.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/decathlon.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/ade.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/stare.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/pascal_context.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/levir.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/night_driving.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/dark_zurich.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/voc.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/basesegdataset.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/cityscapes.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/WatermelonDataset.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/loveda.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/coco_stuff.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/chase_db1.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/lip.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/refuge.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/potsdam.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/synapse.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/mapillary.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/__init__.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/drive.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/isprs.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/isaid.py -> build/lib/mmseg/datasets
# copying mmseg/datasets/dataset_wrappers.py -> build/lib/mmseg/datasets
# creating build/lib/mmseg/models
# copying mmseg/models/data_preprocessor.py -> build/lib/mmseg/models
# copying mmseg/models/builder.py -> build/lib/mmseg/models
# copying mmseg/models/__init__.py -> build/lib/mmseg/models
# creating build/lib/mmseg/engine
# copying mmseg/engine/__init__.py -> build/lib/mmseg/engine
# creating build/lib/mmseg/structures
# copying mmseg/structures/seg_data_sample.py -> build/lib/mmseg/structures
# copying mmseg/structures/__init__.py -> build/lib/mmseg/structures
# creating build/lib/mmseg/visualization
# copying mmseg/visualization/local_visualizer.py -> build/lib/mmseg/visualization
# copying mmseg/visualization/__init__.py -> build/lib/mmseg/visualization
# creating build/lib/mmseg/evaluation
# copying mmseg/evaluation/__init__.py -> build/lib/mmseg/evaluation
# creating build/lib/mmseg/datasets/transforms
# copying mmseg/datasets/transforms/transforms.py -> build/lib/mmseg/datasets/transforms
# copying mmseg/datasets/transforms/__init__.py -> build/lib/mmseg/datasets/transforms
# copying mmseg/datasets/transforms/loading.py -> build/lib/mmseg/datasets/transforms
# copying mmseg/datasets/transforms/formatting.py -> build/lib/mmseg/datasets/transforms
# creating build/lib/mmseg/models/utils
# copying mmseg/models/utils/res_layer.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/embed.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/inverted_residual.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/ppm.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/make_divisible.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/self_attention_block.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/shape_convert.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/wrappers.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/encoding.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/__init__.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/se_layer.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/basic_block.py -> build/lib/mmseg/models/utils
# copying mmseg/models/utils/up_conv_block.py -> build/lib/mmseg/models/utils
# creating build/lib/mmseg/models/losses
# copying mmseg/models/losses/ohem_cross_entropy_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/utils.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/dice_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/cross_entropy_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/accuracy.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/__init__.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/lovasz_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/focal_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/boundary_loss.py -> build/lib/mmseg/models/losses
# copying mmseg/models/losses/tversky_loss.py -> build/lib/mmseg/models/losses
# creating build/lib/mmseg/models/segmentors
# copying mmseg/models/segmentors/base.py -> build/lib/mmseg/models/segmentors
# copying mmseg/models/segmentors/seg_tta.py -> build/lib/mmseg/models/segmentors
# copying mmseg/models/segmentors/__init__.py -> build/lib/mmseg/models/segmentors
# copying mmseg/models/segmentors/cascade_encoder_decoder.py -> build/lib/mmseg/models/segmentors
# copying mmseg/models/segmentors/encoder_decoder.py -> build/lib/mmseg/models/segmentors
# creating build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/pid_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/aspp_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/ham_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/ddr_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/isa_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/stdc_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/ema_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/nl_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/knet_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/lraspp_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/mask2former_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/point_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/gc_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/da_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/decode_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/dm_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/ocr_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/dpt_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/maskformer_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/segformer_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/setr_up_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/sep_fcn_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/fcn_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/fpn_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/cc_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/cascade_decode_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/apc_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/enc_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/__init__.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/dnl_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/uper_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/sep_aspp_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/ann_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/psa_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/segmenter_mask_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/setr_mla_head.py -> build/lib/mmseg/models/decode_heads
# copying mmseg/models/decode_heads/psp_head.py -> build/lib/mmseg/models/decode_heads
# creating build/lib/mmseg/models/necks
# copying mmseg/models/necks/jpu.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/multilevel_neck.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/featurepyramid.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/fpn.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/__init__.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/mla_neck.py -> build/lib/mmseg/models/necks
# copying mmseg/models/necks/ic_neck.py -> build/lib/mmseg/models/necks
# creating build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/mscan.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/resnext.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/bisenetv1.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/vit.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/mobilenet_v3.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/ddrnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/beit.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/mobilenet_v2.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/stdc.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/icnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/twins.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/fast_scnn.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/timm_backbone.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/pidnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/bisenetv2.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/erfnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/__init__.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/cgnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/resnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/mae.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/swin.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/hrnet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/mit.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/unet.py -> build/lib/mmseg/models/backbones
# copying mmseg/models/backbones/resnest.py -> build/lib/mmseg/models/backbones
# creating build/lib/mmseg/engine/optimizers
# copying mmseg/engine/optimizers/layer_decay_optimizer_constructor.py -> build/lib/mmseg/engine/optimizers
# copying mmseg/engine/optimizers/__init__.py -> build/lib/mmseg/engine/optimizers
# creating build/lib/mmseg/engine/hooks
# copying mmseg/engine/hooks/visualization_hook.py -> build/lib/mmseg/engine/hooks
# copying mmseg/engine/hooks/__init__.py -> build/lib/mmseg/engine/hooks
# creating build/lib/mmseg/structures/sampler
# copying mmseg/structures/sampler/ohem_pixel_sampler.py -> build/lib/mmseg/structures/sampler
# copying mmseg/structures/sampler/builder.py -> build/lib/mmseg/structures/sampler
# copying mmseg/structures/sampler/base_pixel_sampler.py -> build/lib/mmseg/structures/sampler
# copying mmseg/structures/sampler/__init__.py -> build/lib/mmseg/structures/sampler
# creating build/lib/mmseg/evaluation/metrics
# copying mmseg/evaluation/metrics/iou_metric.py -> build/lib/mmseg/evaluation/metrics
# copying mmseg/evaluation/metrics/citys_metric.py -> build/lib/mmseg/evaluation/metrics
# copying mmseg/evaluation/metrics/__init__.py -> build/lib/mmseg/evaluation/metrics
# creating build/lib/mmseg/.mim
# copying mmseg/.mim/model-index.yml -> build/lib/mmseg/.mim
# creating build/lib/mmseg/.mim/configs
# creating build/lib/mmseg/.mim/configs/_base_
# copying mmseg/.mim/configs/_base_/default_runtime.py -> build/lib/mmseg/.mim/configs/_base_
# creating build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/WatermelonDataset_pipeline.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/ade20k.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/ade20k_640x640.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/chase_db1.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/cityscapes.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/cityscapes_1024x1024.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/cityscapes_768x768.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/cityscapes_769x769.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/cityscapes_832x832.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/coco-stuff10k.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/coco-stuff164k.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/drive.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/hrf.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/isaid.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/levir_256x256.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/loveda.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/mapillary_v1.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/mapillary_v1_65.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/mapillary_v2.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/pascal_context.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/pascal_context_59.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/pascal_voc12.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/pascal_voc12_aug.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/potsdam.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/refuge.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/stare.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/synapse.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# copying mmseg/.mim/configs/_base_/datasets/vaihingen.py -> build/lib/mmseg/.mim/configs/_base_/datasets
# creating build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/ann_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/apcnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/bisenetv1_r18-d32.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/bisenetv2.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/ccnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/cgnet.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/danet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/deeplabv3_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/deeplabv3_unet_s5-d16.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/deeplabv3plus_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/dmnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/dnl_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/dpt_vit-b16.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/emanet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/encnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/erfnet_fcn.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fast_scnn.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fastfcn_r50-d32_jpu_psp.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fcn_hr18.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fcn_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fcn_unet_s5-d16.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fpn_poolformer_s12.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/fpn_r50.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/gcnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/icnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/isanet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/lraspp_m-v3-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/nonlocal_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/ocrnet_hr18.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/ocrnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/pointrend_r50.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/psanet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/pspnet_r50-d8.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/pspnet_unet_s5-d16.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/segformer_mit-b0.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/segmenter_vit-b16_mask.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/setr_mla.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/setr_naive.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/setr_pup.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/stdc.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/twins_pcpvt-s_fpn.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/twins_pcpvt-s_upernet.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_beit.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_convnext.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_mae.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_r50.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_swin.py -> build/lib/mmseg/.mim/configs/_base_/models
# copying mmseg/.mim/configs/_base_/models/upernet_vit-b16_ln_mln.py -> build/lib/mmseg/.mim/configs/_base_/models
# creating build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_160k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_20k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_240k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_320k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_40k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# copying mmseg/.mim/configs/_base_/schedules/schedule_80k.py -> build/lib/mmseg/.mim/configs/_base_/schedules
# creating build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r101-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/ann_r50-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ann
# copying mmseg/.mim/configs/ann/metafile.yaml -> build/lib/mmseg/.mim/configs/ann
# creating build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r101-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/apcnet_r50-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/apcnet
# copying mmseg/.mim/configs/apcnet/metafile.yaml -> build/lib/mmseg/.mim/configs/apcnet
# creating build/lib/mmseg/.mim/configs/beit
# copying mmseg/.mim/configs/beit/beit-base_upernet_8xb2-160k_ade20k-640x640.py -> build/lib/mmseg/.mim/configs/beit
# copying mmseg/.mim/configs/beit/beit-base_upernet_8xb2-160k_ade20k-640x640_ms.py -> build/lib/mmseg/.mim/configs/beit
# copying mmseg/.mim/configs/beit/beit-large_upernet_8xb1-amp-160k_ade20k-640x640.py -> build/lib/mmseg/.mim/configs/beit
# copying mmseg/.mim/configs/beit/beit-large_upernet_8xb1-amp-160k_ade20k-640x640_ms.py -> build/lib/mmseg/.mim/configs/beit
# copying mmseg/.mim/configs/beit/metafile.yaml -> build/lib/mmseg/.mim/configs/beit
# creating build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r101-d32-in1k-pre_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r101-d32_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r18-d32-in1k-pre_4xb4-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r18-d32-in1k-pre_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r18-d32-in1k-pre_4xb8-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r18-d32_4xb4-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r18-d32_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r50-d32-in1k-pre_4xb4-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r50-d32-in1k-pre_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r50-d32_4xb4-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/bisenetv1_r50-d32_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/bisenetv1
# copying mmseg/.mim/configs/bisenetv1/metafile.yaml -> build/lib/mmseg/.mim/configs/bisenetv1
# creating build/lib/mmseg/.mim/configs/bisenetv2
# copying mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv2
# copying mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-amp-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv2
# copying mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-ohem-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv2
# copying mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb8-160k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/bisenetv2
# copying mmseg/.mim/configs/bisenetv2/metafile.yaml -> build/lib/mmseg/.mim/configs/bisenetv2
# creating build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r101-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/ccnet_r50-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/ccnet
# copying mmseg/.mim/configs/ccnet/metafile.yaml -> build/lib/mmseg/.mim/configs/ccnet
# creating build/lib/mmseg/.mim/configs/cgnet
# copying mmseg/.mim/configs/cgnet/cgnet_fcn_4xb4-60k_cityscapes-680x680.py -> build/lib/mmseg/.mim/configs/cgnet
# copying mmseg/.mim/configs/cgnet/cgnet_fcn_4xb8-60k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/cgnet
# copying mmseg/.mim/configs/cgnet/metafile.yaml -> build/lib/mmseg/.mim/configs/cgnet
# creating build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-base_upernet_8xb2-amp-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-base_upernet_8xb2-amp-160k_ade20k-640x640.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-large_upernet_8xb2-amp-160k_ade20k-640x640.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-small_upernet_8xb2-amp-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-tiny_upernet_8xb2-amp-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/convnext-xlarge_upernet_8xb2-amp-160k_ade20k-640x640.py -> build/lib/mmseg/.mim/configs/convnext
# copying mmseg/.mim/configs/convnext/metafile.yaml -> build/lib/mmseg/.mim/configs/convnext
# creating build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r101-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/danet_r50-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/danet
# copying mmseg/.mim/configs/danet/metafile.yaml -> build/lib/mmseg/.mim/configs/danet
# creating build/lib/mmseg/.mim/configs/ddrnet
# copying mmseg/.mim/configs/ddrnet/ddrnet_23-slim_in1k-pre_2xb6-120k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/ddrnet
# copying mmseg/.mim/configs/ddrnet/ddrnet_23_in1k-pre_2xb6-120k_cityscapes-1024x1024.py -> build/lib/mmseg/.mim/configs/ddrnet
# copying mmseg/.mim/configs/ddrnet/metafile.yaml -> build/lib/mmseg/.mim/configs/ddrnet
# creating build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d16-mg124_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb2-amp-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-20k_coco-stuff10k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-320k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-40k_coco-stuff10k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-40k_pascal-context-480x480.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-40k_pascal-context-59-480x480.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-40k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-80k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-80k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-80k_pascal-context-480x480.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101-d8_4xb4-80k_pascal-context-59-480x480.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101b-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r101b-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r18-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r18-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r18b-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r18b-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb2-40k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb2-40k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb2-80k_cityscapes-512x1024.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb2-80k_cityscapes-769x769.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-160k_ade20k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-160k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-20k_coco-stuff10k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-20k_voc12aug-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-320k_coco-stuff164k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# copying mmseg/.mim/configs/deeplabv3/deeplabv3_r50-d8_4xb4-40k_coco-stuff10k-512x512.py -> build/lib/mmseg/.mim/configs/deeplabv3
# ...
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_pspnet_4xb4-160k_ade20k-512x512.py to mobilenet-v2-d8_pspnet_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_deeplabv3plus_4xb2-80k_cityscapes-512x1024.py to mobilenet-v2-d8_deeplabv3plus_4xb2-80k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_deeplabv3_4xb4-160k_ade20k-512x512.py to mobilenet-v2-d8_deeplabv3_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_fcn_4xb4-160k_ade20k-512x512.py to mobilenet-v2-d8_fcn_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_deeplabv3_4xb2-80k_cityscapes-512x1024.py to mobilenet-v2-d8_deeplabv3_4xb2-80k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_fcn_4xb2-80k_cityscapes-512x1024.py to mobilenet-v2-d8_fcn_4xb2-80k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/mobilenet_v2/mobilenet-v2-d8_deeplabv3plus_4xb4-160k_ade20k-512x512.py to mobilenet-v2-d8_deeplabv3plus_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_swin-l_upernet_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_swin-l_upernet_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_r50-d8_pspnet_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_r50-d8_pspnet_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_r50-d8_fcn_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_r50-d8_fcn_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_swin-t_upernet_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_swin-t_upernet_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_r50-d8_deeplabv3_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_r50-d8_deeplabv3_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_swin-l_upernet_8xb2-adamw-80k_ade20k-640x640.py to knet-s3_swin-l_upernet_8xb2-adamw-80k_ade20k-640x640.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/knet/knet-s3_r50-d8_upernet_8xb2-adamw-80k_ade20k-512x512.py to knet-s3_r50-d8_upernet_8xb2-adamw-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb8-160k_cityscapes-1024x1024.py to bisenetv2_fcn_4xb8-160k_cityscapes-1024x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-ohem-160k_cityscapes-1024x1024.py to bisenetv2_fcn_4xb4-ohem-160k_cityscapes-1024x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-160k_cityscapes-1024x1024.py to bisenetv2_fcn_4xb4-160k_cityscapes-1024x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/bisenetv2/bisenetv2_fcn_4xb4-amp-160k_cityscapes-1024x1024.py to bisenetv2_fcn_4xb4-amp-160k_cityscapes-1024x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb2-40k_cityscapes-512x1024.py to gcnet_r50-d8_4xb2-40k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb2-40k_cityscapes-769x769.py to gcnet_r101-d8_4xb2-40k_cityscapes-769x769.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb4-160k_ade20k-512x512.py to gcnet_r101-d8_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb4-80k_ade20k-512x512.py to gcnet_r50-d8_4xb4-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb2-80k_cityscapes-512x1024.py to gcnet_r50-d8_4xb2-80k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb4-20k_voc12aug-512x512.py to gcnet_r50-d8_4xb4-20k_voc12aug-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb2-80k_cityscapes-769x769.py to gcnet_r101-d8_4xb2-80k_cityscapes-769x769.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb4-160k_ade20k-512x512.py to gcnet_r50-d8_4xb4-160k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb4-40k_voc12aug-512x512.py to gcnet_r101-d8_4xb4-40k_voc12aug-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb2-80k_cityscapes-512x1024.py to gcnet_r101-d8_4xb2-80k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb2-40k_cityscapes-512x1024.py to gcnet_r101-d8_4xb2-40k_cityscapes-512x1024.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb2-80k_cityscapes-769x769.py to gcnet_r50-d8_4xb2-80k_cityscapes-769x769.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb4-40k_voc12aug-512x512.py to gcnet_r50-d8_4xb4-40k_voc12aug-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r50-d8_4xb2-40k_cityscapes-769x769.py to gcnet_r50-d8_4xb2-40k_cityscapes-769x769.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb4-20k_voc12aug-512x512.py to gcnet_r101-d8_4xb4-20k_voc12aug-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/.mim/configs/gcnet/gcnet_r101-d8_4xb4-80k_ade20k-512x512.py to gcnet_r101-d8_4xb4-80k_ade20k-512x512.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/evaluation/metrics/iou_metric.py to iou_metric.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/evaluation/metrics/citys_metric.py to citys_metric.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/evaluation/metrics/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/evaluation/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmseg/version.py to version.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmsegmentation.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/mmsegmentation-1.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mmsegmentation-1.0.0-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/mmsegmentation-1.0.0-py3.10.egg
# Extracting mmsegmentation-1.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Removing mmsegmentation 1.0.0 from easy-install.pth file
# Adding mmsegmentation 1.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/mmsegmentation-1.0.0-py3.10.egg
# Processing dependencies for mmsegmentation==1.0.0
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for prettytable==0.7.2
# Best match: prettytable 0.7.2
# Adding prettytable 0.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.39.3
# Best match: fonttools 4.39.3
# Adding fonttools 4.39.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for mmsegmentation==1.0.0
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmsegmentation
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info
#   writing /tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-9ap_e3hf/mmsegmentation.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.0.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.0.0) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.0.0) (23.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.0.0) (0.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.0.0) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.0.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.0.0) (1.16.0)
# Installing collected packages: mmsegmentation
#   Attempting uninstall: mmsegmentation
#     Found existing installation: mmsegmentation 1.0.0
#     Uninstalling mmsegmentation-1.0.0:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/mmsegmentation-1.0.0-py3.10.egg
#       Removing pth entries from /usr/local/lib/python3.10/dist-packages/easy-install.pth:
#       Removing entry: ./mmsegmentation-1.0.0-py3.10.egg
#       Successfully uninstalled mmsegmentation-1.0.0
#   Running setup.py develop for mmsegmentation
#     Running command python setup.py develop
#     running develop
#     /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer, pypa/build or
#             other standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer, pypa/build or
#             other standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     writing mmsegmentation.egg-info/PKG-INFO
#     writing dependency_links to mmsegmentation.egg-info/dependency_links.txt
#     writing requirements to mmsegmentation.egg-info/requires.txt
#     writing top-level names to mmsegmentation.egg-info/top_level.txt
#     reading manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     adding license file 'LICENSE'
#     writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /usr/local/lib/python3.10/dist-packages/mmsegmentation.egg-link (link to .)
#     Adding mmsegmentation 1.0.0 to easy-install.pth file
#
#     Installed /content/mmsegmentation
# Successfully installed mmsegmentation-1.0.0

# %%
# !wget https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x1024_40k_cityscapes/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth -P checkpoint
# Out:
# --2023-06-14 16:01:12--  https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x1024_40k_cityscapes/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 8.48.85.209, 8.48.85.211, 8.48.85.212, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|8.48.85.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 196205945 (187M) [application/octet-stream]
# Saving to: ‘checkpoint/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth’
#
# pspnet_r50-d8_512x1 100%[===================>] 187.12M  33.9MB/s    in 5.8s
#
# 2023-06-14 16:01:19 (32.3 MB/s) - ‘checkpoint/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth’ saved [196205945/196205945]

# %%
# 检查 Pytorch
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())
# Out:
# Pytorch 版本 2.0.1+cu118
# CUDA 是否可用 True

# %%
# 检查 mmcv
import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print('MMCV版本', mmcv.__version__)
print('CUDA版本', get_compiling_cuda_version())
print('编译器版本', get_compiler_version())
# Out:
# MMCV版本 2.0.0
# CUDA版本 11.8
# 编译器版本 GCC 9.3

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Labelme.zip
# Out:
# --2023-06-14 16:20:00--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Labelme.zip
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12978831 (12M) [application/zip]
# Saving to: ‘Watermelon87_Semantic_Seg_Labelme.zip’
#
# Watermelon87_Semant 100%[===================>]  12.38M  4.91MB/s    in 2.5s
#
# 2023-06-14 16:20:05 (4.91 MB/s) - ‘Watermelon87_Semantic_Seg_Labelme.zip’ saved [12978831/12978831]

# %%
# !unzip /content/mmsegmentation/Watermelon87_Semantic_Seg_Labelme.zip
# Out:
# Archive:  /content/mmsegmentation/Watermelon87_Semantic_Seg_Labelme.zip
#    creating: Watermelon87_Semantic_Seg_Labelme/
#    creating: Watermelon87_Semantic_Seg_Labelme/images/
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/1471253631_2.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/68200_main-1.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/suika011.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R.jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/0778_02.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/piece-watermelon-isolated-white-background-top-view-95945299.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/watermelon-slices.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/watermelon-medium.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/da23-e4580.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (8).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/L007-05_5.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/foods083_img01.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/01bd15599c606aa801201794e1fa30.jpg@1280w_1l_2o_100sh.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/21746.1.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/5b3c8018N634d43bd.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/04_35-2.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (8).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/thum-20180809094803.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/c38e1f595c46d502c75bda7ec9bf6078.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/skmrk03.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/7c75f4c6f3bdd9d61d8782ddff1ff6ac.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/045_sozai_l.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/la_wm_img01.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/maxresdefault.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/dun-soi-hat-dua-hau-lay-nuoc-uong-ban-se-bat-ngo-vi-ket-qua-nuochatduah--u1-1493799084-width500height313.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (9).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/20170613134012_430390.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/ac330c7605098e36de5507d857d0b55c.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP.jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (9).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/alkompis_QGYeyHjwPY-scaled.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/adpDSC_5275-750x499.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/vDMIiCPqS1EC.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/360_F_85084369_iab0VH1ohx2lHtM3OfCncfE9I7VPpl0N.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (14).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/Watermelon.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (7).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/test.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (1).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/24a3a0f8a11ae29f8ccca35c822ac0e2991b4773.png
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/2401-food-tip-image-MAIN.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (3).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (13).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/202007220195_top_img_A.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/69735779_m-5b756b48997fa.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (5).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/istockphoto-849574338-170667a.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (1).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/img56610866.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/dua-hau-1.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (12).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/unnamed.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/huyet-ap-cao-thap-nen-an-gi-kieng-gi-tot-on-dinh-2.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/17897490_93d9666602_z.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/pureform-citrulline.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (15).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/8fe7f149146b6866.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (5).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/depositphotos_204189678-stock-photo-slice-watermelon-white-background.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/e52m_8686.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/uportcocoloni_16696_0.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (10).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/s0569_001_c01.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/ed2de27518d0526380c9bcc9f9fb78333565cce8.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (3).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (2).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/IMG_6865-1024x683.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/31cc9b997d1e3a8ed5b6a3cbf5efd86d.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/pfauwbexemva1nvwobqs.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (4).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/11-loai-trai-cay-dinh-duong-nen-an-hang-ngay-dua-hau.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/1510702494080_melon_NWS_block-low.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (15).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/Manfaat-buah-semangka.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (10).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/o0833068314488481500.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/shutterstock_457769608.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/denn-ke-11-7.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (14).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/468D11D9CB53158C55CF126CFE3D49C0A070758A_size321_w400_h400.png
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/R (4).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (2).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (11).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/OIP (13).jpeg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/img_de56fb30d23e2c761302ba61198a4be4233656.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/8-thuc-pham-chong-cam-cum-1459496975020.jpg
#   inflating: Watermelon87_Semantic_Seg_Labelme/images/img4f375505zik9zj.jpeg
#    creating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/20170613134012_430390.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/la_wm_img01.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (9).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/denn-ke-11-7.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/shutterstock_457769608.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/pfauwbexemva1nvwobqs.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/watermelon-medium.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/IMG_6865-1024x683.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/69735779_m-5b756b48997fa.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/uportcocoloni_16696_0.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/piece-watermelon-isolated-white-background-top-view-95945299.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/depositphotos_204189678-stock-photo-slice-watermelon-white-background.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/unnamed.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (9).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/e52m_8686.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/maxresdefault.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/da23-e4580.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/31cc9b997d1e3a8ed5b6a3cbf5efd86d.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/1471253631_2.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/thum-20180809094803.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/foods083_img01.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/0778_02.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/5b3c8018N634d43bd.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/istockphoto-849574338-170667a.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (8).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/vDMIiCPqS1EC.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/o0833068314488481500.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/test.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/alkompis_QGYeyHjwPY-scaled.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (8).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/04_35-2.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/1510702494080_melon_NWS_block-low.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/c38e1f595c46d502c75bda7ec9bf6078.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/ed2de27518d0526380c9bcc9f9fb78333565cce8.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/ac330c7605098e36de5507d857d0b55c.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/8-thuc-pham-chong-cam-cum-1459496975020.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/Watermelon.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (2).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/01bd15599c606aa801201794e1fa30.jpg@1280w_1l_2o_100sh.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/img_de56fb30d23e2c761302ba61198a4be4233656.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/24a3a0f8a11ae29f8ccca35c822ac0e2991b4773.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (4).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/8fe7f149146b6866.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/skmrk03.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (15).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/21746.1.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (10).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/s0569_001_c01.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/468D11D9CB53158C55CF126CFE3D49C0A070758A_size321_w400_h400.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/adpDSC_5275-750x499.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (14).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/360_F_85084369_iab0VH1ohx2lHtM3OfCncfE9I7VPpl0N.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (4).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (2).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/2401-food-tip-image-MAIN.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/11-loai-trai-cay-dinh-duong-nen-an-hang-ngay-dua-hau.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/68200_main-1.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/suika011.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (11).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (13).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/huyet-ap-cao-thap-nen-an-gi-kieng-gi-tot-on-dinh-2.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/img4f375505zik9zj.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (14).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/202007220195_top_img_A.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/17897490_93d9666602_z.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/img56610866.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (7).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (1).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/L007-05_5.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/7c75f4c6f3bdd9d61d8782ddff1ff6ac.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (3).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (13).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/Manfaat-buah-semangka.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (5).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/pureform-citrulline.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/dun-soi-hat-dua-hau-lay-nuoc-uong-ban-se-bat-ngo-vi-ket-qua-nuochatduah--u1-1493799084-width500height313.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (1).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/045_sozai_l.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (12).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (15).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/dua-hau-1.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/R (5).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/watermelon-slices.json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (10).json
#   inflating: Watermelon87_Semantic_Seg_Labelme/labelme_jsons/OIP (3).json

# %%
# !rm -rf Glomeruli-dataset.zip Glomeruli-dataset
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/Glomeruli-dataset.zip
# !unzip Glomeruli-dataset.zip >> /dev/null # 解压
# !rm -rf Glomeruli-dataset.zip # 删除压缩包
# Out:
# --2023-06-14 16:21:14--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/Glomeruli-dataset.zip
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2628579054 (2.4G) [application/zip]
# Saving to: ‘Glomeruli-dataset.zip’
#
# Glomeruli-dataset.z 100%[===================>]   2.45G  11.1MB/s    in 3m 56s
#
# 2023-06-14 16:25:12 (10.6 MB/s) - ‘Glomeruli-dataset.zip’ saved [2628579054/2628579054]

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Mask.zip
# Out:
# --2023-06-14 16:27:03--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Mask.zip
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13230222 (13M) [application/zip]
# Saving to: ‘Watermelon87_Semantic_Seg_Mask.zip’
#
# Watermelon87_Semant 100%[===================>]  12.62M  4.27MB/s    in 3.0s
#
# 2023-06-14 16:27:08 (4.27 MB/s) - ‘Watermelon87_Semantic_Seg_Mask.zip’ saved [13230222/13230222]

# %%
# !unzip /content/mmsegmentation/Watermelon87_Semantic_Seg_Mask.zip >> /dev/null

# %%
import numpy as np
from PIL import Image
import cv2
import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mask = cv2.imread('Watermelon87_Semantic_Seg_Mask/ann_dir/train/045_sozai_l.png')

# %%
np.unique(mask)
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=uint8)

# %%
plt.imshow(mask[:,:,0])
plt.show()

# %%
import numpy as np

import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDatase

# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/__init__.py -P mmseg/datasets
# Out:
# --2023-06-14 17:16:30--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDatase
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-06-14 17:16:32 ERROR 404: Not Found.
#
# --2023-06-14 17:16:32--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/__init__.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2620 (2.6K) [binary/octet-stream]
# Saving to: ‘mmseg/datasets/__init__.py.1’
#
# __init__.py.1       100%[===================>]   2.56K  --.-KB/s    in 0.002s
#
# 2023-06-14 17:16:33 (1.03 MB/s) - ‘mmseg/datasets/__init__.py.1’ saved [2620/2620]

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDataset.py -P configs/pspnet
# Out:
# --2023-06-14 17:17:31--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDataset.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 344 [binary/octet-stream]
# Saving to: ‘configs/pspnet/pspnet_r50-d8_4xb2-40k_DubaiDataset.py’
#
# pspnet_r50-d8_4xb2- 100%[===================>]     344  --.-KB/s    in 0.002s
#
# 2023-06-14 17:17:33 (135 KB/s) - ‘configs/pspnet/pspnet_r50-d8_4xb2-40k_DubaiDataset.py’ saved [344/344]

# %%
# mmsegmentation/mmseg/datasets/WatermelonDataset.py
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset

@DATASETS.register_module()
class WatermelonDataset(BaseSegDataset):
    # 类别和对应的可视化配色
    METAINFO = {
        # 按照灰度排序 0 1 2 3 4 5
        'classes':['Unlabeled', 'red', 'green', 'white', 'seed-black', 'seed-white'],
        'palette':[[132,41,246], [228,193,110], [152,16,60], [58,221,254], [41,169,226], [155,155,155]]
    }

    # 指定图像扩展名、标注扩展名
    def __init__(self,
                 img_suffix='.jpg',
                 seg_map_suffix='.png',
                 reduce_zero_label=False, # 类别ID为0的类别是否需要除去
                 **kwargs) -> None:
        super().__init__(
            img_suffix=img_suffix,
            seg_map_suffix=seg_map_suffix,
            reduce_zero_label=reduce_zero_label,
            **kwargs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-50b1af2577b6> in <cell line: 5>()
#       4
#       5 @DATASETS.register_module()
# ----> 6 class WatermelonDataset(BaseSegDataset):
#       7     # 类别和对应的可视化配色
#       8     METAINFO = {
#
# /usr/local/lib/python3.10/dist-packages/mmengine/registry/registry.py in _register(module)
#     642         # use it as a decorator: @x.register_module()
#     643         def _register(module):
# --> 644             self._register_module(module=module, module_name=name, force=force)
#     645             return module
#     646
#
# /usr/local/lib/python3.10/dist-packages/mmengine/registry/registry.py in _register_module(self, module, module_name, force)
#     587             if not force and name in self._module_dict:
#     588                 existed_module = self.module_dict[name]
# --> 589                 raise KeyError(f'{name} is already registered in {self.name} '
#     590                                f'at {existed_module.__module__}')
#     591             self._module_dict[name] = module
#
# KeyError: 'WatermelonDataset is already registered in dataset at __main__'

# %%
dataset_type = 'WatermelonDataset' # 数据集类名
data_root = 'Watermelon87_Semantic_Seg_Mask/' # 数据集路径（相对于mmsegmentation主目录）
crop_size = (64, 64)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(
        type='RandomResize',
        scale=(2048, 1024),
        ratio_range=(0.5, 2.0),
        keep_ratio=True),
    dict(type='RandomCrop', crop_size=crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(type='PackSegInputs')
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]
img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
tta_pipeline = [
    dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
    dict(
        type='TestTimeAug',
        transforms=[
            [
                dict(type='Resize', scale_factor=r, keep_ratio=True)
                for r in img_ratios
            ],
            [
                dict(type='RandomFlip', prob=0., direction='horizontal'),
                dict(type='RandomFlip', prob=1., direction='horizontal')
            ], [dict(type='LoadAnnotations')], [dict(type='PackSegInputs')]
        ])
]
train_dataloader = dict(
    batch_size=2,
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='InfiniteSampler', shuffle=True),
    dataset=dict(
        type=dataset_type,
        data_root=data_root,
        data_prefix=dict(
            img_path='img_dir/train', seg_map_path='ann_dir/train'),
        pipeline=train_pipeline))
val_dataloader = dict(
    batch_size=1,
    num_workers=4,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type=dataset_type,
        data_root=data_root,
        data_prefix=dict(
            img_path='img_dir/val', seg_map_path='ann_dir/val'),
        pipeline=test_pipeline))
test_dataloader = val_dataloader

val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
test_evaluator = val_evaluator

# %%
from mmengine import Config
cfg = Config.fromfile('./configs/pspnet/pspnet_r50-d8_4xb2-40k_WatermelonDataset.py')

# %%
cfg.norm_cfg = dict(type='BN', requires_grad=True) # 只使用GPU时，BN取代SyncBN
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# modify num classes of the model in decode/auxiliary head

# 模型 decode/auxiliary 输出头，指定为类别个数
cfg.model.decode_head.num_classes = 6
cfg.model.auxiliary_head.num_classes = 6

# _base_/datasets/DubaiDataset_pipeline.py
cfg.train_dataloader.batch_size = 8

cfg.test_dataloader = cfg.val_dataloader




## configs/_base_/schedules/schedule_40k.py

# 训练迭代次数
cfg.train_cfg.max_iters = 800
# 评估模型间隔
cfg.train_cfg.val_interval = 400
# 日志记录间隔
cfg.default_hooks.logger.interval = 100
# 模型权重保存间隔
cfg.default_hooks.checkpoint.interval = 1500


# 额外配置
# 随机数种子
cfg['randomness'] = dict(seed=0)
# 结果保存目录
cfg.work_dir = '/content/gdrive/MyDrive/ckpt'

# %%
cfg.dump('pspnet-WatermelonDataset_20230614.py')

# %%
print(cfg.pretty_text)
# Out:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(64, 64))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'WatermelonDataset'
# data_root = 'Watermelon87_Semantic_Seg_Mask/'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=8,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=800, val_interval=400)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=1500),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# randomness = dict(seed=0)
# work_dir = '/content/gdrive/MyDrive/ckpt'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 06/14 17:47:56 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/14 17:47:56 - mmengine - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(64, 64))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'WatermelonDataset'
# data_root = 'Watermelon87_Semantic_Seg_Mask/'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=8,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=800, val_interval=400)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=1500),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# randomness = dict(seed=0)
# work_dir = '/content/gdrive/MyDrive/ckpt'
# /usr/local/lib/python3.10/dist-packages/mmengine/utils/manager.py:113: UserWarning: <class 'mmseg.visualization.local_visualizer.SegLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(
# /content/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /content/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /content/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 06/14 17:47:57 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/14 17:47:57 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /content/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
runner.train()
# Out:
# 06/14 17:48:01 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 06/14 17:48:02 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 06/14 17:48:02 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# 06/14 17:48:02 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 06/14 17:48:02 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/14 17:48:02 - mmengine - INFO - Checkpoints will be saved to /content/gdrive/MyDrive/ckpt.
# 06/14 17:48:05 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_WatermelonDataset_20230614_174756
# 06/14 17:48:05 - mmengine - INFO - Iter(train) [  6/800]  lr: 9.9989e-03  eta: 0:07:22  time: 0.5570  data_time: 0.0142  memory: 3975  loss: 0.1476  decode.loss_ce: 0.1033  decode.acc_seg: 33.4961  aux.loss_ce: 0.0443  aux.acc_seg: 25.4364
# 06/14 17:49:00 - mmengine - INFO - Iter(train) [100/800]  lr: 9.9779e-03  eta: 0:06:43  time: 0.5987  data_time: 0.0225  memory: 3975  loss: 0.0687  decode.loss_ce: 0.0472  decode.acc_seg: 87.0972  aux.loss_ce: 0.0216  aux.acc_seg: 85.0464
# 06/14 17:50:00 - mmengine - INFO - Iter(train) [200/800]  lr: 9.9557e-03  eta: 0:05:54  time: 0.5819  data_time: 0.0144  memory: 3975  loss: 0.0711  decode.loss_ce: 0.0491  decode.acc_seg: 82.6874  aux.loss_ce: 0.0220  aux.acc_seg: 66.2903
# 06/14 17:50:59 - mmengine - INFO - Iter(train) [300/800]  lr: 9.9334e-03  eta: 0:04:55  time: 0.5889  data_time: 0.0125  memory: 3975  loss: 0.0546  decode.loss_ce: 0.0378  decode.acc_seg: 73.4070  aux.loss_ce: 0.0168  aux.acc_seg: 76.7700
# 06/14 17:51:59 - mmengine - INFO - Iter(train) [400/800]  lr: 9.9111e-03  eta: 0:03:56  time: 0.5794  data_time: 0.0113  memory: 3975  loss: 0.0694  decode.loss_ce: 0.0508  decode.acc_seg: 81.5643  aux.loss_ce: 0.0185  aux.acc_seg: 80.9174
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 06/14 17:52:59 - mmengine - INFO - per class results:
# 06/14 17:52:59 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | Unlabeled  | 66.23 |  97.4 |
# |    red     | 35.34 | 37.04 |
# |   green    |  3.69 |  3.87 |
# |   white    | 32.72 |  34.3 |
# | seed-black | 39.67 | 48.68 |
# | seed-white |  0.0  |  0.0  |
# +------------+-------+-------+
# 06/14 17:52:59 - mmengine - INFO - Iter(val) [11/11]    aAcc: 70.1700  mIoU: 29.6100  mAcc: 36.8800  data_time: 0.0379  time: 5.4683
# 06/14 17:53:58 - mmengine - INFO - Iter(train) [500/800]  lr: 9.8888e-03  eta: 0:02:57  time: 0.5857  data_time: 0.0136  memory: 10442  loss: 0.0518  decode.loss_ce: 0.0369  decode.acc_seg: 73.7793  aux.loss_ce: 0.0149  aux.acc_seg: 74.2493
# 06/14 17:54:58 - mmengine - INFO - Iter(train) [600/800]  lr: 9.8665e-03  eta: 0:01:58  time: 0.5873  data_time: 0.0140  memory: 3975  loss: 0.0572  decode.loss_ce: 0.0407  decode.acc_seg: 74.9115  aux.loss_ce: 0.0165  aux.acc_seg: 80.1086
# 06/14 17:55:58 - mmengine - INFO - Iter(train) [700/800]  lr: 9.8442e-03  eta: 0:00:59  time: 0.6007  data_time: 0.0223  memory: 3975  loss: 0.0490  decode.loss_ce: 0.0348  decode.acc_seg: 91.5314  aux.loss_ce: 0.0143  aux.acc_seg: 90.8142
# 06/14 17:56:58 - mmengine - INFO - Iter(train) [800/800]  lr: 9.8218e-03  eta: 0:00:00  time: 0.6087  data_time: 0.0253  memory: 3975  loss: 0.0396  decode.loss_ce: 0.0273  decode.acc_seg: 83.1146  aux.loss_ce: 0.0123  aux.acc_seg: 83.2214
# 06/14 17:56:58 - mmengine - INFO - Saving checkpoint at 800 iterations
# 06/14 17:57:11 - mmengine - INFO - per class results:
# 06/14 17:57:11 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | Unlabeled  | 71.41 | 93.78 |
# |    red     | 51.09 | 56.37 |
# |   green    | 39.75 | 46.04 |
# |   white    | 48.49 | 51.09 |
# | seed-black | 50.48 | 57.48 |
# | seed-white |  0.0  |  0.0  |
# +------------+-------+-------+
# 06/14 17:57:11 - mmengine - INFO - Iter(val) [11/11]    aAcc: 77.2600  mIoU: 43.5400  mAcc: 50.7900  data_time: 0.0144  time: 0.4500
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from mmseg.apis import init_model, inference_model, show_result_pyplot
import mmcv
import cv2

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner

register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 06/14 18:08:02 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/14 18:08:02 - mmengine - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(64, 64))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'WatermelonDataset'
# data_root = 'Watermelon87_Semantic_Seg_Mask/'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=8,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='WatermelonDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=800, val_interval=400)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=1500),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# randomness = dict(seed=0)
# work_dir = '/content/gdrive/MyDrive/ckpt'
# /usr/local/lib/python3.10/dist-packages/mmengine/utils/manager.py:113: UserWarning: <class 'mmseg.visualization.local_visualizer.SegLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(
# /content/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /content/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /content/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 06/14 18:08:03 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/14 18:08:03 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /content/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
# 初始化模型
checkpoint_path = '/content/gdrive/MyDrive/ckpt/iter_800.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')
# Out:
# Loads checkpoint by local backend from path: /content/gdrive/MyDrive/ckpt/iter_800.pth

# %%
img = mmcv.imread('fresh-ripe-watermelon-slices-on-wooden-table-royalty-free-image-1684966820.jpg')

# %%
result = inference_model(model, img)

# %%
result.keys()
# Out:
# ['pred_sem_seg', 'seg_logits']

# %%
pred_mask = result.pred_sem_seg.data[0].cpu().numpy()

# %%
pred_mask.shape
# Out:
# (1200, 1200)

# %%
np.unique(pred_mask)
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.imshow(pred_mask)
plt.show()

# %%
# 可视化预测结果
visualization = show_result_pyplot(model, img, result, opacity=0.7, out_file='pred.jpg')
plt.imshow(mmcv.bgr2rgb(visualization))
plt.show()
# Out:
# 06/14 18:10:38 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
